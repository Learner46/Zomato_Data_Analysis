# %%
import pandas as pd
import numpy as np

# %%
pip install openpyxl

# %%
df= pd.read_csv("https://raw.githubusercontent.com/nethajinirmal13/Training-datasets/main/zomato/zomato.csv")

# %%
df_1=pd.read_excel("c:/Users/L/Downloads/Country-Code.xlsx", engine= "openpyxl")

# %%
df_1.head(20)
# Out:
#     Country Code         Country
# 0              1           India
# 1             14       Australia
# 2             30          Brazil
# 3             37          Canada
# 4             94       Indonesia
# 5            148     New Zealand
# 6            162     Phillipines
# 7            166           Qatar
# 8            184       Singapore
# 9            189    South Africa
# 10           191       Sri Lanka
# 11           208          Turkey
# 12           214             UAE
# 13           215  United Kingdom
# 14           216   United States

# %%
df.head(5)
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
col= df[["Average Cost for two"]]
col
# Out:
#       Average Cost for two
# 0                     1100
# 1                     1200
# 2                     4000
# 3                     1500
# 4                     1500
# ...                    ...
# 9546                    80
# 9547                   105
# 9548                   170
# 9549                   120
# 9550                    55
#
# [9551 rows x 1 columns]

# %%
df_2=df.copy()

# %%
df_2.head(2)
# Out:
#    Restaurant ID   Restaurant Name  Country Code         City  \
# 0        6317637  Le Petit Souffle           162  Makati City
# 1        6304287  Izakaya Kikufuji           162  Makati City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
#
#                                     Locality Verbose   Longitude   Latitude  \
# 0  Century City Mall, Poblacion, Makati City, Mak...  121.027535  14.565443
# 1  Little Tokyo, Legaspi Village, Makati City, Ma...  121.014101  14.553708
#
#                      Cuisines  ...          Currency Has Table booking  \
# 0  French, Japanese, Desserts  ...  Botswana Pula(P)               Yes
# 1                    Japanese  ...  Botswana Pula(P)               Yes
#
# ...

# %% [markdown]
# # Handling the Null values

# %%
df_2.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
df_2["Cuisines"].fillna("Not Specified",inplace= True)

# %%
df_2.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                0
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
df_2.dtypes
# Out:
# Restaurant ID             int64
# Restaurant Name          object
# Country Code              int64
# City                     object
# Address                  object
# Locality                 object
# Locality Verbose         object
# Longitude               float64
# Latitude                float64
# Cuisines                 object
# Average Cost for two      int64
# Currency                 object
# Has Table booking        object
# Has Online delivery      object
# Is delivering now        object
# Switch to order menu     object
# Price range               int64
# Aggregate rating        float64
# Rating color             object
# Rating text              object
# Votes                     int64
# dtype: object

# %%
df_3=df_2.copy()

# %%
df_3.head(1)
# Out:
#    Restaurant ID   Restaurant Name  Country Code         City  \
# 0        6317637  Le Petit Souffle           162  Makati City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
#
#                                     Locality  \
# 0  Century City Mall, Poblacion, Makati City
#
#                                     Locality Verbose   Longitude   Latitude  \
# 0  Century City Mall, Poblacion, Makati City, Mak...  121.027535  14.565443
#
#                      Cuisines  ...          Currency Has Table booking  \
# 0  French, Japanese, Desserts  ...  Botswana Pula(P)               Yes
#
#   Has Online delivery Is delivering now Switch to order menu Price range  \
# 0                  No                No                   No           3
#
#    Aggregate rating  Rating color Rating text Votes
# 0               4.8    Dark Green   Excellent   314
#
# [1 rows x 21 columns]

# %%
df_4= pd.merge(df_3,df_1, on="Country Code",how="left")

# %%
df_4.head(1)
# Out:
#    Restaurant ID   Restaurant Name  Country Code         City  \
# 0        6317637  Le Petit Souffle           162  Makati City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
#
#                                     Locality  \
# 0  Century City Mall, Poblacion, Makati City
#
#                                     Locality Verbose   Longitude   Latitude  \
# 0  Century City Mall, Poblacion, Makati City, Mak...  121.027535  14.565443
#
#                      Cuisines  ...  Has Table booking Has Online delivery  \
# 0  French, Japanese, Desserts  ...                Yes                  No
#
#   Is delivering now Switch to order menu Price range Aggregate rating  \
# 0                No                   No           3              4.8
#
#    Rating color  Rating text Votes      Country
# 0    Dark Green    Excellent   314  Phillipines
#
# [1 rows x 22 columns]

# %%
df_4.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                0
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# Country                 0
# dtype: int64

# %%
df_4.isna().sum().sum()
# Out:
# 0

# %%
currency_column = df_4.loc[:, 'Currency']
print(currency_column)
# Out:
# 0       Botswana Pula(P)
# 1       Botswana Pula(P)
# 2       Botswana Pula(P)
# 3       Botswana Pula(P)
# 4       Botswana Pula(P)
#               ...
# 9546    Turkish Lira(TL)
# 9547    Turkish Lira(TL)
# 9548    Turkish Lira(TL)
# 9549    Turkish Lira(TL)
# 9550    Turkish Lira(TL)
# Name: Currency, Length: 9551, dtype: object

# %%
df_4['Currency_1'] = 'rupees'

# %%
currency_column_1 = df_4.loc[:, 'Currency_1']
print(currency_column_1)
# Out:
# 0       rupees
# 1       rupees
# 2       rupees
# 3       rupees
# 4       rupees
#          ...
# 9546    rupees
# 9547    rupees
# 9548    rupees
# 9549    rupees
# 9550    rupees
# Name: Currency_1, Length: 9551, dtype: object

# %%
df_4.head(1)
# Out:
#    Restaurant ID   Restaurant Name  Country Code         City  \
# 0        6317637  Le Petit Souffle           162  Makati City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
#
#                                     Locality  \
# 0  Century City Mall, Poblacion, Makati City
#
#                                     Locality Verbose   Longitude   Latitude  \
# 0  Century City Mall, Poblacion, Makati City, Mak...  121.027535  14.565443
#
#                      Cuisines  ...  Has Online delivery Is delivering now  \
# 0  French, Japanese, Desserts  ...                   No                No
#
#   Switch to order menu Price range Aggregate rating Rating color  Rating text  \
# 0                   No           3              4.8   Dark Green    Excellent
#
#    Votes      Country Currency_1
# 0    314  Phillipines     rupees
#
# [1 rows x 23 columns]

# %%
df_4.dtypes
# Out:
# Restaurant ID             int64
# Restaurant Name          object
# Country Code              int64
# City                     object
# Address                  object
# Locality                 object
# Locality Verbose         object
# Longitude               float64
# Latitude                float64
# Cuisines                 object
# Average Cost for two      int64
# Currency                 object
# Has Table booking        object
# Has Online delivery      object
# Is delivering now        object
# Switch to order menu     object
# Price range               int64
# Aggregate rating        float64
# Rating color             object
# Rating text              object
# Votes                     int64
# Country                  object
# Currency_1               object
# dtype: object

# %%
#saving the new file
df_4.to_csv("zomato.csv", index= False)
